# %% [markdown]
# PRÁTICA - web scraping

# %%
# !pip install requests

# %%
# !pip freeze

# %%
import requests

# %%
x = requests.get('https://dolarhoje.com.br')
print(x.status_code)
# Out:
# 200

# %%
x.content
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en">\r\n  <head>\r\n\r\n<!-- Google Tag Manager -->\r\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\r\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\r\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\r\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\r\n})(window,document,\'script\',\'dataLayer\',\'GTM-PRD7ZL4\');</script>\r\n<!-- End Google Tag Manager -->\r\n\r\n    <meta charset="utf-8">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1">\r\n    <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->\r\n    <meta name="description" content="D\xc3\xb3lar Hoje - Valor da Cota\xc3\xa7\xc3\xa3o - Pre\xc3\xa7o Comercial | dolarhoje.com.br">\r\n    <meta name="author" content="">\r\n    <link rel="shortcut icon" href="/favicon.ico">\r\n    \r\n    <!-- Title -->\r\n    <title>D\xc3\xb3lar Hoje - Valor da Cota\xc3\xa7\xc3\xa3o - Pre\xc3\xa7o Comercial | dolarhoje.com.br</title>\r\n    \r\n    <!-- Necessary CSS Files -->\r\n    <link href="https://fonts.googleapis.com/css?family=Montserrat:300,400,500,600,700" rel="stylesheet">\t \t<!-- Google Font -->\r\n    <link href="css/bootstrap.min.css" rel="stylesheet">\t\t\t\t\t\t\t\t\t\t\t\t<!-- bootstrap  -->\r\n    <link href="css/style.css" rel="stylesheet">\t\t\t\t\t\t\t\t\t\t\t\t\t\t<!-- Template Main css  -->\r\n    <link href="css/jquery.bxslider.css" rel="stylesheet" />\t\t\t\t\t\t\t\t\t\t\t<!-- Client Logo Slider  -->\r\n    <link rel="stylesheet" type="text/css" href="css/slick.css">\t\t\t\t\t\t\t\t\t\t<!-- Testimonial Slider -->\r\n    <link rel="stylesheet" type="text/css" href="css/slick-theme.css">\t\t\t\t\t\t\t\t\t<!-- Testimonial Slider -->\r\n    <link rel="stylesheet" type="text/css" href="css/jquery.fancybox.css" media="screen" />\t\t\t\t<!-- Video Popup -->\r\n    <link rel="stylesheet" href="css/animate.css">\t\t\t\t\t\t\t\t\t\t\t\t\t\t<!-- Wow Animation CSS -->\r\n\r\n\t<!--RESPONSIVE TAB -->\r\n    <link rel="stylesheet" type="text/css" href="css/easy-responsive-tabs.css " />\r\n    \r\n    <style>\r\n    .peq{\r\n    \tcolor:#fff;\r\n    \tfont-size:24px;\r\n    }\r\n    </style>\r\n    \r\n  </head>\r\n  <body>\r\n<!-- Google Tag Manager (noscript) -->\r\n<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-PRD7ZL4"\r\nheight="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>\r\n<!-- End Google Tag Manager (noscript) -->\r\n  <div class="se-pre-con"></div>\r\n  <!-- header -->\r\n    <div class="header" id="header">\r\n       <div class="container">\r\n          <div class="row header-top" data-spy="affix" data-offset-top="70">\r\n          <div class="container">\r\n\t\t\t\t<div class="row">\r\n             <div class="col-lg-3 col-md-3">\r\n               <div class="logo"><a href="/"><img src="images/logo.png" alt="logo"></a></div>\r\n                 <div id="menu-icon"><span></span><span></span><span></span></div>\r\n                 <div class="clear"></div>\r\n\r\n             </div>\r\n             <div class="col-lg-9 col-md-9" id="menu">\r\n               <div class="menu">\r\n                  <ul>\r\n                    <li><a href="/dolar-turismo">D\xc3\xb3lar Turismo</a></li>\r\n                    <li><a href="/dolar-ptax">D\xc3\xb3lar Ptax</a></li>\r\n                    <li><a href="/dolar-paralelo">D\xc3\xb3lar Paralelo</a></li>\r\n                    <li><a href="https://www.melhorcambio.com/dolar-hoje" target="_blank" rel=\xe2\x80\x9dnofollow\xe2\x80\x9d>D\xc3\xb3lar Hoje</a></li>\r\n                    <li><a href="/euro-turismo">Euro Turismo</a></li>\r\n                    <li><a href="https://www.melhorcambio.com/conversor-de-moeda" target="_blank" rel=\xe2\x80\x9dnofollow\xe2\x80\x9d>Conversor de Moeda</a></li ...

# %%
x.text
# Out:
# '<!DOCTYPE html>\r\n<html lang="en">\r\n  <head>\r\n\r\n<!-- Google Tag Manager -->\r\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\r\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\r\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\r\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\r\n})(window,document,\'script\',\'dataLayer\',\'GTM-PRD7ZL4\');</script>\r\n<!-- End Google Tag Manager -->\r\n\r\n    <meta charset="utf-8">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1">\r\n    <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->\r\n    <meta name="description" content="Dólar Hoje - Valor da Cotação - Preço Comercial | dolarhoje.com.br">\r\n    <meta name="author" content="">\r\n    <link rel="shortcut icon" href="/favicon.ico">\r\n    \r\n    <!-- Title -->\r\n    <title>Dólar Hoje - Valor da Cotação - Preço Comercial | dolarhoje.com.br</title>\r\n    \r\n    <!-- Necessary CSS Files -->\r\n    <link href="https://fonts.googleapis.com/css?family=Montserrat:300,400,500,600,700" rel="stylesheet">\t \t<!-- Google Font -->\r\n    <link href="css/bootstrap.min.css" rel="stylesheet">\t\t\t\t\t\t\t\t\t\t\t\t<!-- bootstrap  -->\r\n    <link href="css/style.css" rel="stylesheet">\t\t\t\t\t\t\t\t\t\t\t\t\t\t<!-- Template Main css  -->\r\n    <link href="css/jquery.bxslider.css" rel="stylesheet" />\t\t\t\t\t\t\t\t\t\t\t<!-- Client Logo Slider  -->\r\n    <link rel="stylesheet" type="text/css" href="css/slick.css">\t\t\t\t\t\t\t\t\t\t<!-- Testimonial Slider -->\r\n    <link rel="stylesheet" type="text/css" href="css/slick-theme.css">\t\t\t\t\t\t\t\t\t<!-- Testimonial Slider -->\r\n    <link rel="stylesheet" type="text/css" href="css/jquery.fancybox.css" media="screen" />\t\t\t\t<!-- Video Popup -->\r\n    <link rel="stylesheet" href="css/animate.css">\t\t\t\t\t\t\t\t\t\t\t\t\t\t<!-- Wow Animation CSS -->\r\n\r\n\t<!--RESPONSIVE TAB -->\r\n    <link rel="stylesheet" type="text/css" href="css/easy-responsive-tabs.css " />\r\n    \r\n    <style>\r\n    .peq{\r\n    \tcolor:#fff;\r\n    \tfont-size:24px;\r\n    }\r\n    </style>\r\n    \r\n  </head>\r\n  <body>\r\n<!-- Google Tag Manager (noscript) -->\r\n<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-PRD7ZL4"\r\nheight="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>\r\n<!-- End Google Tag Manager (noscript) -->\r\n  <div class="se-pre-con"></div>\r\n  <!-- header -->\r\n    <div class="header" id="header">\r\n       <div class="container">\r\n          <div class="row header-top" data-spy="affix" data-offset-top="70">\r\n          <div class="container">\r\n\t\t\t\t<div class="row">\r\n             <div class="col-lg-3 col-md-3">\r\n               <div class="logo"><a href="/"><img src="images/logo.png" alt="logo"></a></div>\r\n                 <div id="menu-icon"><span></span><span></span><span></span></div>\r\n                 <div class="clear"></div>\r\n\r\n             </div>\r\n             <div class="col-lg-9 col-md-9" id="menu">\r\n               <div class="menu">\r\n                  <ul>\r\n                    <li><a href="/dolar-turismo">Dólar Turismo</a></li>\r\n                    <li><a href="/dolar-ptax">Dólar Ptax</a></li>\r\n                    <li><a href="/dolar-paralelo">Dólar Paralelo</a></li>\r\n                    <li><a href="https://www.melhorcambio.com/dolar-hoje" target="_blank" rel=”nofollow”>Dólar Hoje</a></li>\r\n                    <li><a href="/euro-turismo">Euro Turismo</a></li>\r\n                    <li><a href="https://www.melhorcambio.com/conversor-de-moeda" target="_blank" rel=”nofollow”>Conversor de Moeda</a></li>\r\n                  </ul>\r\n               </div>\r\n             </div>\r\n             \t</div>\r\n\t\t\t</div>\r\n\r\n     ...

# %%
x.text.index('US$')
# Out:
# 3876

# %%
conteudo = x.content

# %%
str(x.content).index('US$')
# Out:
# 4273

# %%
texto = x.text
posA = texto.find('US$')
posA
# Out:
# 3876

# %%
texto[posA:]
# Out:
# 'US$ 1,00 <span class="peq">vale</span> R$ 5,38 <span class="peq">hoje</span></h1>\r\n                <p class="wow fadeInDown">Atualizado em 15/06/2024 às 20:58</p>\r\n                <div class="bnts wow fadeInUp" style="padding-top: 60px">\r\n                   <a href="https://www.melhorcambio.com" target="_blank" rel=”nofollow”" class="btn2">COTAÇÃO DO DÓLAR TURISMO?</a>\r\n                   <!--img src="/img/banner_home_1.jpg" width="700"-->\r\n                </div>\r\n             </div>\r\n          </div>\r\n          \r\n          <div class="row">\r\n            <div class="col-lg-12">\r\n              <div class="toping">\r\n                <a href="https://www.melhorcambio.com" target="_blank">\r\n                \t<img class="img-responsive cenetr-block" src="images/topimg.png"  alt="hero-image">\r\n                </a>\r\n              </div>\r\n            </div>\r\n          </div>\r\n       </div>\r\n    </div>\r\n   <!-- header End-->\r\n   \r\n   <!-- Clients Logo--> \r\n   <div class="section12" style="padding-top: 80px">\r\n       <!-- div class="container">\r\n       <div class="row">\r\n          <div class="col-lg-12 col-md-12 col-sm-12">\r\n             <div class="slider1">\r\n                   <div class="slide"><img src="images/lg1.png" alt="brand-logo"></div>\r\n                   <div class="slide"><img src="images/lg2.png" alt="brand-logo"></div>\r\n                   <div class="slide"><img src="images/lg3.png" alt="brand-logo"></div>\r\n                   <div class="slide"><img src="images/lg4.png" alt="brand-logo"></div>\r\n                   <div class="slide"><img src="images/lg1.png" alt="brand-logo"></div>\r\n                   <div class="slide"><img src="images/lg2.png" alt="brand-logo"></div>\r\n                   <div class="slide"><img src="images/lg3.png" alt="brand-logo"></div>\r\n                   <div class="slide"><img src="images/lg4.png" alt="brand-logo"></div>                  \r\n\r\n             </div>\r\n             \r\n          </div>\r\n        </div>\r\n      </div-->\r\n    </div> \r\n    <!-- Clients Logo End-->   \r\n   \r\n \t<!-- features >\r\n     <div class="section2" id="features">\r\n       <div class="container">\r\n          <div class="row">\r\n          <div class="col-lg-12">\r\n             <div class="heading">\r\n                <span>features</span>\r\n                <h2>Best features ever</h2>\r\n             </div>\r\n          </div>\r\n          </div>\r\n          <div class="row">\r\n          <div class="col-lg-4 col-md-4 col-sm-6 module">\r\n             <div class="f-box wow fadeInUp" data-wow-duration="1s">\r\n               <div class="f-img"><img src="images/icon1.png" alt="f1"></div>\r\n               <a href="#">Friendly Admin</a>\r\n               <p>Lorem Ipsum is simply dummy text the printing and typeseing industry Lorem Ipsum has been standard.</p>\r\n             </div>\r\n          </div>\r\n          \r\n          <div class="col-lg-4 col-md-4 col-sm-6 module">\r\n             <div class="f-box wow fadeInUp" data-wow-duration="2s">\r\n               <div class="f-img"><img src="images/icon2.png" alt="f2"></div>\r\n               <a href="#">Well Documented</a>\r\n               <p>Lorem Ipsum is simply dummy text the printing and typeseing industry Lorem Ipsum has been standard.</p>\r\n             </div>\r\n          </div>\r\n          \r\n          <div class="col-lg-4 col-md-4 col-sm-6 module">\r\n             <div class="f-box wow fadeInUp" data-wow-duration="2s">\r\n               <div class="f-img"><img src="images/icon3.png" alt="f3"></div>\r\n               <a href="#">Highly Customizable</a>\r\n               <p>Lorem Ipsum is simply dummy text the printing and typeseing industry Lorem Ipsum has been standard.</p>\r\n             </div>\r\n          </div>\r\n          \r\n          <div class="col-lg-4 col-md-4 col-sm-6 module">\r\n             <div class="f-box wow fadeInUp" data-wow-duration="2s">\r\n          ...

# %%
posB = texto.index('hoje', 3876)
posB
# Out:
# 3941

# %%
trecho = texto[posA:posB]
trecho
# Out:
# 'US$ 1,00 <span class="peq">vale</span> R$ 5,38 <span class="peq">'

# %%
#buscar ponto inicial

# %%
#buscar ponto final

# %%
#capturar trecho de interesse
trecho = str(conteudo)[:]
trecho
# Out:
# 'b\'<!DOCTYPE html>\\r\\n<html lang="en">\\r\\n  <head>\\r\\n\\r\\n<!-- Google Tag Manager -->\\r\\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\\\'gtm.start\\\':\\r\\nnew Date().getTime(),event:\\\'gtm.js\\\'});var f=d.getElementsByTagName(s)[0],\\r\\nj=d.createElement(s),dl=l!=\\\'dataLayer\\\'?\\\'&l=\\\'+l:\\\'\\\';j.async=true;j.src=\\r\\n\\\'https://www.googletagmanager.com/gtm.js?id=\\\'+i+dl;f.parentNode.insertBefore(j,f);\\r\\n})(window,document,\\\'script\\\',\\\'dataLayer\\\',\\\'GTM-PRD7ZL4\\\');</script>\\r\\n<!-- End Google Tag Manager -->\\r\\n\\r\\n    <meta charset="utf-8">\\r\\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\\r\\n    <meta name="viewport" content="width=device-width, initial-scale=1">\\r\\n    <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->\\r\\n    <meta name="description" content="D\\xc3\\xb3lar Hoje - Valor da Cota\\xc3\\xa7\\xc3\\xa3o - Pre\\xc3\\xa7o Comercial | dolarhoje.com.br">\\r\\n    <meta name="author" content="">\\r\\n    <link rel="shortcut icon" href="/favicon.ico">\\r\\n    \\r\\n    <!-- Title -->\\r\\n    <title>D\\xc3\\xb3lar Hoje - Valor da Cota\\xc3\\xa7\\xc3\\xa3o - Pre\\xc3\\xa7o Comercial | dolarhoje.com.br</title>\\r\\n    \\r\\n    <!-- Necessary CSS Files -->\\r\\n    <link href="https://fonts.googleapis.com/css?family=Montserrat:300,400,500,600,700" rel="stylesheet">\\t \\t<!-- Google Font -->\\r\\n    <link href="css/bootstrap.min.css" rel="stylesheet">\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t<!-- bootstrap  -->\\r\\n    <link href="css/style.css" rel="stylesheet">\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t<!-- Template Main css  -->\\r\\n    <link href="css/jquery.bxslider.css" rel="stylesheet" />\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t<!-- Client Logo Slider  -->\\r\\n    <link rel="stylesheet" type="text/css" href="css/slick.css">\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t<!-- Testimonial Slider -->\\r\\n    <link rel="stylesheet" type="text/css" href="css/slick-theme.css">\\t\\t\\t\\t\\t\\t\\t\\t\\t<!-- Testimonial Slider -->\\r\\n    <link rel="stylesheet" type="text/css" href="css/jquery.fancybox.css" media="screen" />\\t\\t\\t\\t<!-- Video Popup -->\\r\\n    <link rel="stylesheet" href="css/animate.css">\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t\\t<!-- Wow Animation CSS -->\\r\\n\\r\\n\\t<!--RESPONSIVE TAB -->\\r\\n    <link rel="stylesheet" type="text/css" href="css/easy-responsive-tabs.css " />\\r\\n    \\r\\n    <style>\\r\\n    .peq{\\r\\n    \\tcolor:#fff;\\r\\n    \\tfont-size:24px;\\r\\n    }\\r\\n    </style>\\r\\n    \\r\\n  </head>\\r\\n  <body>\\r\\n<!-- Google Tag Manager (noscript) -->\\r\\n<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-PRD7ZL4"\\r\\nheight="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>\\r\\n<!-- End Google Tag Manager (noscript) -->\\r\\n  <div class="se-pre-con"></div>\\r\\n  <!-- header -->\\r\\n    <div class="header" id="header">\\r\\n       <div class="container">\\r\\n          <div class="row header-top" data-spy="affix" data-offset-top="70">\\r\\n          <div class="container">\\r\\n\\t\\t\\t\\t<div class="row">\\r\\n             <div class="col-lg-3 col-md-3">\\r\\n               <div class="logo"><a href="/"><img src="images/logo.png" alt="logo"></a></div>\\r\\n                 <div id="menu-icon"><span></span><span></span><span></span></div>\\r\\n                 <div class="clear"></div>\\r\\n\\r\\n             </div>\\r\\n             <div class="col-lg-9 col-md-9" id="menu">\\r\\n               <div class="menu">\\r\\n                  <ul>\\r\\n                    <li><a href="/dolar-turismo">D\\xc3\\xb3lar Turismo</a></li>\\r\\n                    <li><a href="/dolar-ptax">D\\xc3\\xb3lar Ptax</a></li>\\r\\n                    <li><a href="/dolar-paralelo">D\\xc3\\xb3lar Paralelo</a></li>\\r\\n                    <li><a href="https://www.melhorcambio.com/dolar-hoje" target="_blank" rel=\\xe2\\x80\\x9dnof ...

# %% [markdown]
# ##Tratamento

# %%
conteudo = x.content

# %%
str(conteudo).index('US$ 1,00')
# Out:
# 4273

# %%
str(conteudo).index('\\n', 4273)
# Out:
# 4356

# %%
trecho = str(conteudo)[4273:4356]
trecho
# Out:
# 'US$ 1,00 <span class="peq">vale</span> R$ 5,38 <span class="peq">hoje</span></h1>\\r'

# %% [markdown]
# ## Biblioteca Regex

# %%
import re

# %% [markdown]
# ### função sub

# %%
trecho
# Out:
# 'US$ 1,00 <span class="peq">vale</span> R$ 5,38 <span class="peq">hoje</span></h1>\\r'

# %%
cotacao = re.sub(" ", "_", trecho)
type(cotacao)
# Out:
# str

# %%
cotacao
# Out:
# 'US$_1,00_<span_class="peq">vale</span>_R$_5,38_<span_class="peq">hoje</span></h1>\\r'

# %% [markdown]
# ### função split

# %%
cotacao = re.split(" ", trecho)
type(cotacao)
# Out:
# list

# %%
cotacao
# Out:
# ['US$',
#  '1,00',
#  '<span',
#  'class="peq">vale</span>',
#  'R$',
#  '5,38',
#  '<span',
#  'class="peq">hoje</span></h1>\\r']

# %% [markdown]
# ### função findall

# %%
cotacao = re.findall(" ", trecho)
type(cotacao)
# Out:
# list

# %%
cotacao
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
teste = re.findall("R\S.*", "R$ 4,48  R$ 5,32  R$ 45,00  R$ 123,00")
teste
# Out:
# ['R$ 4,48  R$ 5,32  R$ 45,00  R$ 123,00']

# %% [markdown]
# ### função search

# %%
cotacao = re.search("R\S (.{4})", trecho)
type(cotacao)
# Out:
# re.Match

# %%
cotacao
# Out:
# <re.Match object; span=(39, 46), match='R$ 5,38'>

# %%
cotacao.string
# Out:
# 'US$ 1,00 <span class="peq">vale</span> R$ 5,38 <span class="peq">hoje</span></h1>\\r'

# %%
cotacao.span()
# Out:
# (39, 46)

# %%
cotacao.group()
# Out:
# 'R$ 5,38'

# %%
cotacao.group(1)
# Out:
# '5,38'

# %%
valor = cotacao.group(1).replace(',','.')
valor = round(float(valor), 2)
valor
# Out:
# 5.38

# %%
valor * 140
# Out:
# 753.1999999999999

# %%
teste = re.search("R\S (.{4})", " R$ 45,00  R$ 4,00  R$ 6,00 ")
teste
# Out:
# <re.Match object; span=(1, 8), match='R$ 45,0'>
