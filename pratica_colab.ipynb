# %% [markdown]
# PRÁTICA - introdução ao google colab

# %% [markdown]
# # Gravação de Arquivo - arquivo.py

# %%
#python arquivo.py

arquivo = 'meu_arquivo.txt'
f = open(arquivo, 'a')

f.write("Este é meu primeiro arquivo\n")
f.flush()

f.close()

# %%
arquivo = 'meu_arquivo.txt'
f = open(arquivo, 'r')

content = f.readlines()

f.close()

print(content)
# Out:
# ['Este é meu primeiro arquivo\n', 'Este é meu primeiro arquivo\n', 'Este é meu primeiro arquivo\n']

# %% [markdown]
# # Mapeamento de Google Drive

# %%
from google.colab import drive
drive.mount('/content/aqui/')
# Out:
# Mounted at /content/aqui/

# %%
drive.flush_and_unmount()

# %%
# !cp "/content/aqui/MyDrive/WebMining_Scraping_DE05/AULA1/pratica_colab.csv" .

# %%
# !cat pratica_colab.csv
# Out:
# fruta;2020;2021;2022;2023
# maçãs;800;600;300;600
# laranjas;600;700;450;350
# bananas;200;350;550;250
# abacaxi;375;400;480;500

# %%
import pandas as pd

df = pd.read_csv('/content/aqui/MyDrive/WebMining_Scraping_DE05/AULA1/pratica_colab.csv', delimiter=';')
df
# Out:
#       fruta  2020  2021  2022  2023
# 0     maçãs   800   600   300   600
# 1  laranjas   600   700   450   350
# 2   bananas   200   350   550   250
# 3   abacaxi   375   400   480   500

# %% [markdown]
# # Alternativa - Upload de arquivo

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8eabe60a-947c-40dc-8c8d-8317ad6237e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8eabe60a-947c-40dc-8c8d-8317ad6237e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#!cat pratica_colab.csv
# Out:
# fruta;2020;2021;2022;2023
# maçãs;800;600;300;600
# laranjas;600;700;450;350
# bananas;200;350;550;250
# abacaxi;375;400;480;500

# %%
#!pip install requests
# Out:
# 4 pratica_colab.csv

# %%
# !pip freeze

# %%
import pandas as pd

df = pd.read_csv('pratica_colab.csv', delimiter=';')
df.head()
# Out:
#       fruta  2020  2021  2022  2023
# 0     maçãs   800   600   300   600
# 1  laranjas   600   700   450   350
# 2   bananas   200   350   550   250
# 3   abacaxi   375   400   480   500

# %% [markdown]
# ACESSO AWS S3 (BUCKET)

# %%
# !pip install boto3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 38.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 11.3 MB/s eta 0:00:00
# ...

# %%
#!pip install boto3
import boto3

#aws_access_key_id = ''
#aws_secret_access_key = ''
#aws_session_token=''

s3 = boto3.resource('s3', aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key, aws_session_token=aws_session_token)

obj = s3.Object('takeshi-bucket-s3','teste-final.txt')

data=obj.get()['Body'].read()

print(data)
# Out:
# b'TESTANDO EC2 e S3\nUTILIZANDO NANO\n\n'
